# %%
import torch

def rbf_expand(distances, centers, gamma):
    return torch.exp(-gamma * (distances[..., None] - centers) ** 2)

# Example
centers = torch.linspace(0, 5, 16)  # 16 RBF centers from 0 to 5 Å
gamma = 10.0
distances = torch.tensor([1.0, 1.5, 3.2])  # bond lengths

rbf_feats = rbf_expand(distances, centers, gamma)

# %%
print("RBF features shape:", rbf_feats.shape)
# Out:
# RBF features shape: torch.Size([3, 16])

# %%
print("RBF features:" , rbf_feats)
# Out:
# RBF features: tensor([[4.5400e-05, 1.1744e-02, 3.2919e-01, 1.0000e+00, 3.2919e-01, 1.1744e-02,
#          4.5400e-05, 1.9020e-08, 8.6351e-13, 4.2484e-18, 2.2651e-24, 1.3087e-31,
#          8.1940e-40, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [1.6919e-10, 1.2268e-06, 9.6398e-04, 8.2085e-02, 7.5747e-01, 7.5746e-01,
#          8.2085e-02, 9.6397e-04, 1.2268e-06, 1.6919e-10, 2.5286e-15, 4.0953e-21,
#          7.1878e-28, 1.3671e-35, 2.8026e-44, 0.0000e+00],
#         [2.8026e-45, 2.0448e-36, 1.3426e-28, 9.5531e-22, 7.3663e-16, 6.1554e-11,
#          5.5739e-07, 5.4697e-04, 5.8166e-02, 6.7032e-01, 8.3713e-01, 1.1329e-01,
#          1.6616e-03, 2.6408e-06, 4.5483e-10, 8.4891e-15]])

# %%
# Plotting the RBF features
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
for i in range(rbf_feats.shape[0]):
    plt.plot(centers.numpy(), rbf_feats[i].numpy(), label=f"Distance {distances[i].item()} Å")
plt.title("Radial Basis Function (RBF) Features")
plt.xlabel("RBF Centers")
plt.ylabel("RBF Value")
plt.legend()
plt.grid()
plt.show()
