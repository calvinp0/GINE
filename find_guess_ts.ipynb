# %%
from rdkit import Chem
from rdkit.Chem import rdmolops

# Load molecules from SDF string or file
suppl = Chem.SDMolSupplier('/home/calvin/code/chemprop_phd_customised/habnet/data/processed/sdf_data/rxn_3248.sdf', removeHs=False, sanitize=True)
mol_r1h = suppl[0]
mol_r2h = suppl[1]

# %%
import pandas as pd

rxn_feats = pd.read_csv('/home/calvin/code/chemprop_phd_customised/habnet/data/processed/target_data/target_data_sin_cos.csv')
rxn_ids = rxn_feats['rxn'].tolist()

# %%
len(rxn_ids)
# Out:
# 1696

# %%
'rxn_1850' in rxn_ids
# Out:
# True

# %%
import os
import re

ts_dict = {}

def has_valid_ts_log(folder_path):
    for log_name in ['input.log', 'output.log', 'output.out']:
        log_path = os.path.join(folder_path, log_name)
        if os.path.exists(log_path):
            with open(log_path, 'r') as f:
                for line in reversed(f.readlines()):
                    if 'Normal termination' in line:
                        return True
    return False

def try_ts_guess_fallback(base_path):
    for tsg in ['tsg0', 'tsg1']:
        guess_path = os.path.join(base_path, 'calcs', 'TS_guesses','TS0', tsg)
        if not os.path.exists(guess_path):
            continue
        for file in os.listdir(guess_path):
            if file == 'AutoTST F.xyz':
                return os.path.join(guess_path, file)
        for file in os.listdir(guess_path):
            if 'Heuristic' in file and file.endswith('.xyz'):
                return os.path.join(guess_path, file)
    return None

base_dir = "/home/calvin/Dropbox/PersonalFolders/Calvin/"

for folder_1 in os.listdir(base_dir):
    if folder_1.endswith("Converged"):
        folder_1_path = os.path.join(base_dir, folder_1)
        for folder_2 in os.listdir(folder_1_path):
            if folder_2 in rxn_ids:
                ts0_path = os.path.join(folder_1_path, folder_2, "calcs", "TSs", "TS0")
                if os.path.exists(ts0_path):
                    subfolders = os.listdir(ts0_path)
                    ts_found = False
                    for folder_3 in subfolders:
                        if re.match(r"^conformer\d+$", folder_3) or re.match(r"^conf_opt_\d+$", folder_3):
                            full_path = os.path.join(ts0_path, folder_3)
                            if has_valid_ts_log(full_path):
                                ts_dict[folder_2] = full_path
                                ts_found = True
                                break
                    # Fallback if no conformer/conf_opt_ found
                    if not ts_found:
                        fallback_xyz = try_ts_guess_fallback(os.path.join(folder_1_path, folder_2))
                        if fallback_xyz:
                            ts_dict[folder_2] = fallback_xyz
            elif folder_2 == 'NonRMG':
                for folder_2a in os.listdir(f"/home/calvin/Dropbox/PersonalFolders/Calvin/{folder_1}/{folder_2}"):
                    if folder_2a in rxn_ids:

                        ts0_path = os.path.join(folder_1_path,folder_2, folder_2a, "calcs", "TSs", "TS0")
                        if os.path.exists(ts0_path):
                            subfolders = os.listdir(ts0_path)
                            ts_found = False
                            for folder_3 in subfolders:
                                if re.match(r"^conformer\d+$", folder_3) or re.match(r"^conf_opt_\d+$", folder_3):
                                    full_path = os.path.join(ts0_path, folder_3)
                                    if has_valid_ts_log(full_path):
                                        ts_dict[folder_2a] = full_path
                                        ts_found = True
                                        break
                            # Fallback if no conformer/conf_opt_ found
                            if not ts_found:
                                fallback_xyz = try_ts_guess_fallback(os.path.join(folder_1_path,folder_2, folder_2a))
                                if fallback_xyz:
                                    ts_dict[folder_2a] = fallback_xyz

# %%
len(ts_dict)
# Out:
# 1696

# %%
for rxn in rxn_ids:
    if rxn not in ts_dict:
        print(rxn)

# %%
ts_dict_long = ts_dict.copy()

# %%
len(ts_dict_long)
# Out:
# 1696

# %%
for rxn in rxn_ids:
    if rxn not in ts_dict_long:
        print(rxn)

# %%
import numpy as np

def find_archive_end(lines):
    for i in range(len(lines) - 1, -1, -1):
        if lines[i].strip().endswith("\\@") or lines[i].strip() == "@":
            return i
        # Handle wrapped case: line is a backslash, next is just '@'
        if lines[i].strip() == "\\" and i+1 < len(lines) and lines[i+1].strip() == "@":
            return i+1  # Point to the '@' line
    return None

def extract_final_xyz_archive_block(logfile: str) -> tuple[list[str], np.ndarray]:
    with open(logfile, "r") as f:
        lines = [line.strip() for line in f]

    # Step 1: Find the last line containing '\@'
    end_idx = find_archive_end(lines)
    if end_idx is None:
        print(f"WARNING: File {logfile} has no recognizable archive block end (\\@ or @) — skipping.")
        return None, None

    # Step 2: Find the last preceding line containing '\\0,1\\' or '\\0,2\\' or '\\0,3\\'
    start_idx = None
    for i in range(end_idx, -1, -1):
        if '\\0,1\\' in lines[i] or '\\0,2\\' in lines[i] or '\\0,3\\' in lines[i]:
            start_idx = i
            break
    if start_idx is None:
        raise ValueError("Could not find start of Gaussian archive coordinate block (\\0,1\\ or \\0,2\\)")

    # Step 3: Join all lines between start and end into a single string
    archive_block = "".join(lines[start_idx:end_idx + 1])

    # Step 4: Isolate the part after '\0,1' or '\0,2'
    if "\\0,1" in archive_block:
        archive_block = archive_block.split("\\0,1", 1)[-1]
    elif "\\0,2" in archive_block:
        archive_block = archive_block.split("\\0,2", 1)[-1]

    # Step 5: Split into coordinate entries
    entries = archive_block.strip("\\").split("\\")
    symbols = []
    coords = []

    for entry in entries:
        fields = entry.split(",")
        if len(fields) != 4:
            continue
        sym, x, y, z = fields
        try:
            symbols.append(sym)
            coords.append([float(x), float(y), float(z)])
        except Exception:
            continue

    if not symbols or not coords:
        raise ValueError("No atomic coordinates found in Gaussian archive block.")

    return symbols, np.array(coords, dtype=np.float64)


def parse_xyz_like_ts_file(filepath):
    atoms = []
    coords = []

    with open(filepath, 'r') as f:
        lines = f.readlines()

    if not lines:
        raise ValueError(f"{filepath} is empty or unreadable.")

    # Format A: Heuristic
    if lines[0].strip() == "Heuristic":
        atom_lines = lines[2:]  # Skip "Heuristic" and atom count
    # Format B: AutoTST
    elif len(lines) > 1 and lines[1].strip() == "AutoTST F":
        atom_lines = lines[2:]  # Skip count and "AutoTST F"
    # Format C: Generic XYZ (no special label)
    else:
        atom_lines = lines[2:]  # Generic XYZ fallback

    for line in atom_lines:
        parts = line.strip().split()
        if len(parts) != 4:
            continue  # Skip malformed lines
        symbol, x, y, z = parts
        atoms.append(symbol)
        coords.append([float(x), float(y), float(z)])

    return atoms, coords

# %%
extract_final_xyz_archive_block('/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_13108/calcs/TSs/TS0/conformer7/input.log')
# Out:
# (['O', 'C', 'C', 'C', 'C', 'O', 'H', 'C', 'C', 'N', 'O', 'N', 'H', 'H'],
#  array([[ 1.46429571, -2.88826418,  0.27005411],
#         [ 0.84678924, -1.8637572 ,  0.27700193],
#         [ 0.0889378 , -1.33768504,  1.39571334],
#         [-0.57347939, -0.83748909,  2.28096086],
#         [-1.33844914, -0.21528658,  3.3570049 ],
#         [-2.49749654, -0.44964642,  3.56217808],
#         [-0.75155304,  0.50261694,  3.97493304],
#         [ 0.50132604,  0.40771824, -1.69631094],
#         [ 0.55866197,  0.84593791, -3.04854742],
#         [ 0.18071576,  2.09266348, -3.04821366],
#         [-0.09627471,  2.41501059, -1.77134905],
#         [ 0.10664111,  1.3584926 , -0.9360323 ],
#         [ 0.80298755, -1.17788009, -0.63658862],
#         [ 0.84364709,  0.32789031, -3.96014246]]))

# %%
import re
def get_expected_atom_count(logfile: str) -> int:
    """
    Parses the Gaussian log file to extract the number of atoms from the Symbolic Z-matrix section.
    """
    atom_count = 0
    found = False
    with open(logfile, "r") as f:
        for line in f:
            if 'Symbolic Z-matrix:' in line:
                found = True
                continue
            if found:
                # Check for lines starting with element symbol (e.g., "C", "N", "O", "H", etc.)
                m = re.match(r'^\s*([A-Z][a-z]?)\b', line)
                if m:
                    atom_count += 1
                elif line.strip() == "" or not re.match(r'^[A-Z]', line.strip()):
                    break  # End of Z-matrix
    if not found or atom_count == 0:
        raise ValueError("Could not extract atom count from Symbolic Z-matrix")
    return atom_count


get_expected_atom_count('/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_13108/calcs/TSs/TS0/conformer7/input.log') 


from collections import Counter

def parse_xyz_like_ts_file(filepath):
    atoms = []
    coords = []

    with open(filepath, 'r') as f:
        lines = f.readlines()

    if not lines:
        raise ValueError(f"{filepath} is empty or unreadable.")

    # Determine format and get atomic lines
    if lines[0].strip() == "Heuristic":
        atom_lines = lines[2:]  # Skip label and count
    elif len(lines) > 1 and lines[1].strip() == "AutoTST F":
        atom_lines = lines[2:]  # Skip count and label
    else:
        atom_lines = lines[2:]  # Assume generic XYZ

    for line in atom_lines:
        parts = line.strip().split()
        if len(parts) != 4:
            continue
        symbol, x, y, z = parts
        atoms.append(symbol)
        coords.append([float(x), float(y), float(z)])

    atom_counter = Counter(atoms)

    return atoms, coords, atom_counter

# %%
results = {}


def try_extract_block(path_dir):
    for fname in ["input.log", "output.log", "output.out"]:
        fpath = os.path.join(path_dir, fname)
        if os.path.exists(fpath):
            result = extract_final_xyz_archive_block(fpath)
            if result:
                return result
    return None

def try_atom_count(path_dir):
    for fname in ["input.log", "output.log", "output.out"]:
        fpath = os.path.join(path_dir, fname)
        if os.path.exists(fpath):
            count = get_expected_atom_count(fpath)
            if count:
                return count
    return None
for key, value in ts_dict_long.items():
    try:
        if os.path.isdir(value):
            atom_count = try_atom_count(value)
            if atom_count is None:
                raise ValueError(f"No atom count found for {key}")

            symbols_coords = try_extract_block(value)
            if symbols_coords is None:
                raise ValueError(f"No geometry block found for {key}")

            symbols, coords = symbols_coords

            if len(symbols) != atom_count:
                raise ValueError(f"Mismatch in atom count for {key}: expected {atom_count}, found {len(symbols)}")

            atom_counter = Counter(symbols)

        elif os.path.isfile(value) and value.endswith(".xyz"):
            symbols, coords, atom_counter = parse_xyz_like_ts_file(value)
            atom_count = len(symbols)

        else:
            raise ValueError(f"Unrecognized TS path type: {value}")

        results[key] = {
            'path': value,
            'atom_count': atom_count,
            'symbols': symbols,
            'coords': coords,
            'atom_counter': atom_counter,
        }

    except Exception as e:
        print(f"Error for {key}: {e}")

# %%
ts_dict_long['rxn_1890']
# Out:
# '/home/calvin/Dropbox/PersonalFolders/Calvin/HAb_Converged/rxn_1890/calcs/TSs/TS0/conformer6'

# %%
len(list(results.keys()))
# Out:
# 1696

# %%
results
# Out:
# {'kfir_rxn_13712': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_13712/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['C',
#    'O',
#    'C',
#    'C',
#    'N',
#    'H',
#    'H',
#    'N',
#    'C',
#    'C',
#    'C',
#    'N',
#    'H',
#    'H'],
#   'coords': array([[ 1.38149964,  0.82179534,  0.01608109],
#          [ 1.88450681,  0.29147471,  1.16155457],
#          [ 1.21244313,  1.54834007,  1.27555664],
#          [-0.08106911,  1.52572081,  1.93991914],
#          [-1.12277861,  1.49532147,  2.43765801],
#          [ 2.03720395,  1.08463818, -0.82493293],
#          [ 1.85415711,  2.3994826 ,  1.52809082],
#          [-1.60955379,  0.78316861, -2.96217397],
#          [-1.31820935,  0.21463748, -1.99813966],
#          [-0.89540409, -0.42962386, -0.77475416],
#          [-0.56385743, -1.8328521 , -0.87651997],
#          [-0.24734408, -2.94382666, -0.92892534],
#          [ 0.19998919,  0.16623139, -0.43838783],
#          [-1.56444965, -0.21228703,  0.0707279 ]]),
#   'atom_counter': Counter({'C': 6, 'H': 4, 'N': 3, 'O': 1})},
#  'kfir_rxn_13503': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_13503/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['C',
#    'C',
#    'N',
#    'C',
#    'S',
#    'H',
#    'H',
#    'O',
#    'C',
#    'C',
#    'Cl',
#    'Cl',
#    'Cl',
#    'H'],
#   'coords': array([[ 0.32983467, -2.18204814,  0.1550868 ],
#          [ 0.47314286, -1.84027457,  1.57192482],
#          [-0.57539825, -1.97641477,  2.33031904],
#          [-1.6171635 , -2.63254521,  1.73172692],
#          [-1.31278617, -2.86202723,  0.0431071 ],
#          [ 1.1185105 , -2.77219044, -0.33194476],
#          [ 1.39470681, -1.39965141,  1.96809855],
#          [ 0.67981017,  0.11261147, -2.49986672],
#          [ 0.5129275 ,  0.15933517, -1.34019756],
#          [ 0.28773286,  1.4156129 , -0.46617572],
#          [-1.22428227,  1.13913644,  0.41928504],
#          [ 0.20544562,  2.89355504, -1.43115996],
#          [ 1.67607722,  1.46780935,  0.65151656],
#          [ 0.41537713, -1.09301793, -0.46988796]]),
#   'atom_counter': Counter({'C': 5, 'H': 3, 'Cl': 3, 'N': 1, 'S': 1, 'O': 1})},
#  'kfir_rxn_9205': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_9205/calcs/TSs/TS0/conformer4',
#   'atom_count': 10,
#   'symbols': ['N', 'C', 'C', 'N', 'N', 'H', 'H', 'O', 'H', 'H'],
#   'coords': array([[ 0.9749387 ,  0.18825557, -0.29171147],
#          [-0.21400291, -0.41881472, -0.11375353],
#          [-0.96085833,  0.4836596 ,  0.60571971],
#          [-0.16982651,  1.56524973,  0.83534293],
#          [ 0.9918277 ,  1.38471821,  0.29436209],
#          [ 1.79647349, -0.16218649, -0.77064039],
#          [-1.98119775,  0.41874306,  0.97215061],
#          [-0.45708106, -2.41010675, -1.4145423 ],
#          [-0.4246823 , -1.64226114, -0.57762277],
#          [-1.03884852, -1.97031055, -2.05387513]]),
#   'atom_counter': Counter({'H': 4, 'N': 3, 'C': 2, 'O': 1})},
#  'kfir_rxn_8057': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_8057/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['N',
#    'C',
#    'N',
#    'C',
#    'N',
#    'H',
#    'H',
#    'C',
#    'C',
#    'N',
#    'N',
#    'O',
#    'H',
#    'H'],
#   'coords': array([[-0.49058621, -1.64253525,  0.34051125],
#          [ 0.30426246, -1.18130114,  1.36649713],
#          [ 1.34744303, -0.47641092,  1.16945107],
#          [-0.11330218, -1.63339355,  2.69661466],
#          [-0.42012243, -1.96507308,  3.76043783],
#          [-1.47869254, -1.73582924,  0.58243781],
#          [ 1.84971817, -0.29731297,  2.03839145],
#          [ 0.55883706,  1.13553148, -1.47357746],
#          [-0.39737688,  0.17322944, -1.39376113],
#          [-1.38569661,  0.50545372, -2.25486803],
#          [-1.09468304,  1.57554252, -2.85159452],
#          [ 0.14234564,  2.00781545, -2.38092675],
#          [ 1.50982706,  1.29055508, -0.97386761],
#          [-0.38399139, -0.93630258, -0.63183964]]),
#   'atom_counter': Counter({'N': 5, 'C': 4, 'H': 4, 'O': 1})},
#  'kfir_rxn_9652': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_9652/calcs/TSs/TS0/conformer6',
#   'atom_count': 10,
#   'symbols': ['O', 'C', 'C', 'N', 'H', 'H', 'N', 'H', 'H', 'H'],
#   'coords': array([[ 0.26628627,  0.39889817,  1.49659683],
#          [ 0.53128873,  0.35431218,  0.14224372],
#          [-0.60503297,  0.82135741, -0.63834216],
#          [-1.49917534,  1.13243563, -1.30208262],
#          [ 1.05592749,  0.11821738,  1.96941197],
#          [ 1.44609809,  0.8904609 , -0.16954535],
#          [ 0.6610545 , -2.16010586, -0.57325848],
#          [ 0.7406594 , -0.8130275 , -0.21469316],
#          [-0.1652396 , -2.40842248, -0.00987666],
#          [ 0.26492655, -2.05454182, -1.51879702]]),
#   'atom_counter': Counter({'H': 5, 'C': 2, 'N': 2, 'O': 1})},
#  'kfir_rxn_9248': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_9248/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['N',
#    'N',
#    'C',
#    'C',
#    'N',
#    'H',
#    'H',
#    'O',
#    'C',
#    'C',
#    'N',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-4.27044943e-01, -7.93816339e-01,  1.29628745e+00],
#          [-5.45692288e-01, -7.39718863e-01,  2.22017150e-03],
#          [-1.68393967e+00, -1.32848426e+00, -4.56343470e-01],
#          [-2.34842788e+00, -1.80208149e+00,  6.61194692e-01],
#          [-1.51409812e+00, -1.43170395e+00,  1.67110093e+00],
#          [-1.92330966e+00, -1.36881898e+00, -1.51455661e+00],
#          [-1.65523577e+00, -1.59686828e+00,  2.66222274e+00],
#          [ 1.78167700e+00,  5.32421557e-01, -2.14337319e+00],
#          [ 1.59551746e+00,  5.79183663e-01, -7.83376644e-01],
#          [ 1.40554626e+00,  1.89182720e+00, -2.04054228e-01],
#          [ 1.16399483e+00,  2.93919365e+00,  2.29199496e-01],
#          [ 1.21644819e+00,  1.18490786e+00, -2.57221511e+00],
#          [ 4.72938441e-01, -9.08148866e-02, -4.76897595e-01],
#          [ 2.36169043e+00, -1.32012516e-02, -2.67194868e-01]]),
#   'atom_counter': Counter({'H': 5, 'N': 4, 'C': 4, 'O': 1})},
#  'kfir_rxn_7559': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_7559/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['N',
#    'C',
#    'N',
#    'C',
#    'N',
#    'H',
#    'H',
#    'C',
#    'C',
#    'O',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-1.97477448,  0.70000891,  2.13708047],
#          [-0.99620764,  0.4329163 ,  1.22333731],
#          [-0.91041812, -0.67986718,  0.60331366],
#          [-0.03294237,  1.52086989,  1.04745921],
#          [ 0.72787002,  2.37752424,  0.89829192],
#          [-2.73164691,  0.0320281 ,  2.21151497],
#          [-2.16291128,  1.65597432,  2.4041931 ],
#          [ 1.19624184, -0.6085797 , -0.89990218],
#          [ 1.02089457, -1.68964608, -1.89607062],
#          [ 0.56976286, -1.51973358, -3.00170831],
#          [ 0.13036243, -0.71046938, -0.17698271],
#          [ 2.00611894, -0.7619865 , -0.17532356],
#          [ 1.16057262,  0.40051236, -1.32837409],
#          [ 1.31114387, -2.71300094, -1.54830407]]),
#   'atom_counter': Counter({'H': 6, 'C': 4, 'N': 3, 'O': 1})},
#  'kfir_rxn_7125': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_7125/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['N',
#    'N',
#    'N',
#    'C',
#    'C',
#    'N',
#    'H',
#    'O',
#    'C',
#    'C',
#    'Cl',
#    'Cl',
#    'Cl',
#    'H'],
#   'coords': array([[-0.06306717, -1.75327224,  1.617275  ],
#          [-0.01680159, -2.82439079,  2.30997589],
#          [ 0.04454928, -4.0276723 ,  1.7266048 ],
#          [ 0.0504827 , -4.11697084,  0.41964917],
#          [ 0.00603971, -2.96351077, -0.43085985],
#          [-0.04598914, -1.88667844,  0.28687252],
#          [ 0.0961434 , -5.129792  ,  0.00757467],
#          [-0.10129692, -0.0115907 , -2.34766207],
#          [-0.06705626,  0.26815975, -1.20520254],
#          [ 0.0216164 ,  1.6938219 , -0.60648375],
#          [-1.45293561,  1.89997361,  0.36416128],
#          [ 0.13547133,  2.93470846, -1.85989659],
#          [ 1.46709962,  1.6979416 ,  0.42731772],
#          [-0.07425449, -0.79853289, -0.26953829]]),
#   'atom_counter': Counter({'N': 4, 'C': 4, 'Cl': 3, 'H': 2, 'O': 1})},
#  'kfir_rxn_7531': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_7531/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['C',
#    'O',
#    'C',
#    'O',
#    'H',
#    'H',
#    'H',
#    'O',
#    'C',
#    'O',
#    'N',
#    'C',
#    'O',
#    'H'],
#   'coords': array([[-0.22766217,  3.84746195,  1.16088428],
#          [-0.19476798,  2.48042373,  0.74780885],
#          [ 0.32693318,  2.23522456, -0.43700355],
#          [ 0.78046723,  3.01654977, -1.21247931],
#          [-0.82707932,  4.44477799,  0.4599253 ],
#          [-0.68604454,  3.85235196,  2.15471765],
#          [ 0.79041356,  4.25844531,  1.20663885],
#          [ 0.62841278, -3.57545002,  0.89890886],
#          [ 0.216632  , -2.63751934,  0.31852383],
#          [-0.85121377, -2.56433607, -0.49091287],
#          [-0.98773053, -1.23597457, -0.97852315],
#          [-0.01426301, -0.63831741, -0.4419334 ],
#          [ 0.77010558, -1.35648179,  0.34871307],
#          [ 0.27580154,  1.09114608, -0.61741607]]),
#   'atom_counter': Counter({'O': 5, 'C': 4, 'H': 4, 'N': 1})},
#  'kfir_rxn_11915': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_11915/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['C',
#    'C',
#    'S',
#    'C',
#    'N',
#    'H',
#    'H',
#    'O',
#    'C',
#    'C',
#    'N',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-0.60231899,  0.17342223,  0.29972101],
#          [ 0.01225156,  0.66234257, -0.81451221],
#          [-0.06799835,  2.3839403 , -0.7396088 ],
#          [-0.90325986,  2.26563782,  0.76920366],
#          [-1.10353735,  1.04727525,  1.18137219],
#          [ 0.49287548,  0.12582612, -1.63080654],
#          [-1.22196517,  3.15829075,  1.31093771],
#          [-0.55654736, -2.2563058 ,  0.7490476 ],
#          [ 0.79784233, -2.50231866,  0.86771936],
#          [ 1.52400274, -2.4051225 , -0.41967695],
#          [ 2.0490733 , -2.27163347, -1.4401362 ],
#          [-0.71036029, -1.1042656 ,  0.52412085],
#          [ 1.30240028, -1.84029007,  1.59538615],
#          [ 0.90522393, -3.53251409,  1.24944873]]),
#   'atom_counter': Counter({'C': 5, 'H': 5, 'N': 2, 'S': 1, 'O': 1})},
#  'kfir_rxn_10218': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_10218/calcs/TSs/TS0/conformer11',
#   'atom_count': 14,
#   'symbols': ['O',
#    'C',
#    'C',
#    'O',
#    'C',
#    'O',
#    'H',
#    'C',
#    'C',
#    'O',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[ 0.36859985, -0.45545632,  1.51321585],
#          [ 1.09327593, -0.83969385,  0.56507419],
#          [ 2.35542453, -1.45642045,  0.86615527],
#          [ 3.30476996, -1.93032799,  1.29538589],
#          [ 0.96290267, -0.77528793, -0.82570579],
#          [-0.07590369, -0.23671006, -1.35239487],
#          [ 1.74342601, -1.18691947, -1.48573171],
#          [-2.32996596,  1.14627179,  0.13717981],
#          [-2.4514643 ,  1.10765093, -1.31077658],
#          [-2.06149503,  2.26508687, -0.76416618],
#          [-1.44407106,  0.71058302,  0.6210205 ],
#          [-3.21607705,  1.30252677,  0.76244798],
#          [-0.8662086 ,  0.17332393, -1.7531616 ],
#          [-3.29123807,  1.04049592, -2.01495003]]),
#   'atom_counter': Counter({'C': 5, 'H': 5, 'O': 4})},
#  'kfir_rxn_679': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_679/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['N',
#    'N',
#    'C',
#    'Cl',
#    'N',
#    'C',
#    'N',
#    'C',
#    'C',
#    'O',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[ 2.56995508, -0.51308116,  0.79783685],
#          [ 1.52605651, -0.48892489,  1.63903421],
#          [ 0.34160993, -0.3362085 ,  1.12390122],
#          [-1.04495026, -0.32072094,  2.14121221],
#          [ 0.1644262 , -0.19150862, -0.1913736 ],
#          [ 1.17390267, -0.21112103, -1.05183233],
#          [ 2.42254623, -0.40189287, -0.47460323],
#          [-1.95232211,  0.47475894, -1.54400052],
#          [-1.58640414,  0.10817278, -2.90452185],
#          [-1.42704192,  1.43032101, -2.34489168],
#          [-0.93711674,  0.04657717, -0.6540858 ],
#          [-2.94009783,  0.60774559, -1.08062539],
#          [-0.64059482, -0.41889064, -3.070703  ],
#          [-2.35005038,  0.03921648, -3.68657459]]),
#   'atom_counter': Counter({'N': 4, 'C': 4, 'H': 4, 'Cl': 1, 'O': 1})},
#  'kfir_rxn_10391': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_10391/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['O',
#    'C',
#    'N',
#    'O',
#    'C',
#    'N',
#    'H',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-0.9678994 ,  0.64825391, -0.58765729],
#          [-0.59653182,  0.72635859,  0.64438728],
#          [-1.45609124,  0.63991334,  1.65148664],
#          [-0.68220682,  0.84407127,  2.75315859],
#          [ 0.57632804,  0.99074158,  2.33430505],
#          [ 0.7083022 ,  0.93265918,  1.0581017 ],
#          [ 1.33744645,  1.14349297,  3.09867851],
#          [ 0.12399751, -1.54390339, -4.09858711],
#          [ 0.13865152, -1.53324761, -2.88356911],
#          [ 0.12808403, -1.47343739, -1.46223297],
#          [ 0.11650215, -1.56136577, -5.17280307],
#          [-0.43307782, -0.40668123, -1.14144695],
#          [ 1.11664833, -1.35175695, -0.99802645],
#          [-0.48363956, -2.24397497, -0.97404352]]),
#   'atom_counter': Counter({'C': 5, 'H': 5, 'O': 2, 'N': 2})},
#  'kfir_rxn_4836': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_4836/calcs/TS_guesses/TS0/tsg0/Heuristics_0.xyz',
#   'atom_count': 13,
#   'symbols': ['N', 'C', 'C', 'C', 'N', 'N', 'O', 'C', 'C', 'C', 'C', 'H', 'H'],
#   'coords': [[-3.06873352, -2.11e-06, 1.40849973],
#    [-1.93383003, -9e-07, 1.57528194],
#    [-0.52657844, 1.2e-07, 1.74435534],
#    [0.4944692, 1.2e-07, 0.8590467],
#    [1.64061764, 9.6e-07, 1.60659275],
#    [1.36723009, 1.19e-06, 2.82518664],
#    [-0.01796442, 9e-08, 2.9744161],
#    [0.4944692, 1.2e-07, -5.47936726],
#    [0.4944692, 1.2e-07, -4.27946892],
#    [0.4944692, 1.2e-07, -2.90692196],
#    [0.4944692, 1.2e-07, -1.70702362],
#    [0.4944692, 1.2e-07, -6.54307157],
#    [0.4944692, 1.2e-07, -0.43057844]],
#   'atom_counter': Counter({'C': 7, 'N': 3, 'H': 2, 'O': 1})},
#  'kfir_rxn_13651': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_13651/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['O',
#    'C',
#    'C',
#    'C',
#    'N',
#    'H',
#    'H',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-1.28022889,  0.69188003,  1.74530858],
#          [-0.4359086 ,  0.22593844,  0.85521801],
#          [ 0.64983345,  1.02951692,  0.70085577],
#          [ 0.35490999,  2.06956278,  1.63107291],
#          [-0.78067165,  1.88071724,  2.25251694],
#          [ 1.50502336,  0.90522542,  0.04472659],
#          [ 0.94031255,  2.95732003,  1.86868074],
#          [ 1.1076624 , -2.51110185, -2.10407495],
#          [ 0.15802511, -2.36365128, -1.36815738],
#          [-0.95783676, -2.1525597 , -0.47666206],
#          [ 1.9440856 , -2.65514707, -2.76228607],
#          [-0.78068471, -1.14204388,  0.11877356],
#          [-1.04860049, -2.93099169,  0.29330048],
#          [-1.91183603, -2.01524419, -1.0039809 ]]),
#   'atom_counter': Counter({'C': 6, 'H': 6, 'O': 1, 'N': 1})},
#  'kfir_rxn_1315': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_1315/calcs/TSs/TS0/conformer6',
#   'atom_count': 13,
#   'symbols': ['O', 'C', 'C', 'O', 'H', 'H', 'H', 'N', 'C', 'O', 'H', 'H', 'H'],
#   'coords': array([[-0.49921205,  1.08423126, -0.46648942],
#          [ 0.41832312,  1.92619374,  0.09109865],
#          [ 1.68389535,  1.30609733,  0.66306261],
#          [ 1.87806183,  0.13524554,  0.84153963],
#          [ 0.0192043 ,  2.56404515,  0.91429881],
#          [ 0.77339856,  2.62762978, -0.69030099],
#          [ 2.45072371,  2.06773975,  0.95358863],
#          [-0.78585015, -0.84326565,  0.81800673],
#          [-1.26664587, -1.87726652,  0.0491427 ],
#          [-2.09252676, -1.76253104, -0.82107535],
#          [-0.87657638,  0.27006833,  0.28207617],
#          [ 0.14345635, -1.02463225,  1.20410062],
#          [-0.86038027, -2.87470712,  0.35173125]]),
#   'atom_counter': Counter({'H': 6, 'O': 3, 'C': 3, 'N': 1})},
#  'kfir_rxn_5389': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_5389/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['O',
#    'C',
#    'N',
#    'C',
#    'C',
#    'H',
#    'H',
#    'N',
#    'C',
#    'C',
#    'C',
#    'N',
#    'H',
#    'H'],
#   'coords': array([[ 0.9484382 ,  0.72008592, -0.08745734],
#          [ 0.68203018,  0.93608002,  1.19716568],
#          [-0.4306893 ,  0.66594767,  1.74297324],
#          [ 1.85665903,  1.51229753,  1.82683297],
#          [ 2.82373312,  1.99452997,  2.36815903],
#          [-0.4172317 ,  0.89677906,  2.73507317],
#          [ 3.68272013,  2.42238913,  2.85383733],
#          [-1.43814322, -0.23927097, -3.49198364],
#          [-1.3192107 , -0.38121148, -2.35105214],
#          [-1.1548209 , -0.51027574, -0.91616533],
#          [-0.99549232, -1.8660438 , -0.42688978],
#          [-0.85018828, -2.938012  , -0.02075032],
#          [-0.14346987,  0.07239384, -0.63461067],
#          [-1.913617  ,  0.03958365, -0.34233532]]),
#   'atom_counter': Counter({'C': 6, 'H': 4, 'N': 3, 'O': 1})},
#  'kfir_rxn_5161': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_5161/calcs/TS_guesses/TS0/tsg0/Heuristics_4.xyz',
#   'atom_count': 12,
#   'symbols': ['C', 'C', 'C', 'O', 'H', 'H', 'H', 'C', 'H', 'H', 'H', 'H'],
#   'coords': [[-1.72666517, 0.56080756, 1.33070762],
#    [-0.73164739, 0.36724702, 0.69354197],
#    [0.46955369, 0.15504173, -0.11707134],
#    [1.08307407, 1.35527449, -0.53149283],
#    [-2.61070283, 0.73277916, 1.89680647],
#    [1.21452777, -0.38353549, 0.47017762],
#    [0.4176708, 1.90980661, -0.94279176],
#    [0.46955369, -2.31786315, -0.99140305],
#    [0.46955369, -1.0858562, -0.55580896],
#    [1.35870148, -2.83116132, -0.62842991],
#    [-0.41956019, -2.83120202, -0.62839782],
#    [0.46955369, -2.31786315, -2.08035711]],
#   'atom_counter': Counter({'H': 7, 'C': 4, 'O': 1})},
#  'kfir_rxn_5172': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_5172/calcs/TSs/TS0/conformer6',
#   'atom_count': 11,
#   'symbols': ['C', 'C', 'C', 'O', 'H', 'H', 'H', 'C', 'O', 'H', 'H'],
#   'coords': array([[-0.23835545,  0.93127541, -0.5681127 ],
#          [-0.23008074,  0.89025498,  0.71595019],
#          [-0.21397751,  0.70535267,  2.03496692],
#          [ 0.88974192,  0.64023388,  2.81226807],
#          [-0.27013214,  1.78255114, -1.25412821],
#          [-1.13677368,  0.6158394 ,  2.6143795 ],
#          [ 1.67158338,  0.73520454,  2.25657176],
#          [-0.20304044, -1.44791484, -1.89744706],
#          [-0.12917906, -1.54717726, -3.0743188 ],
#          [-0.21733553, -0.25832803, -1.25165386],
#          [-0.27055225, -2.32789107, -1.19463745]]),
#   'atom_counter': Counter({'H': 5, 'C': 4, 'O': 2})},
#  'kfir_rxn_4303': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_4303/calcs/TSs/TS0/conformer6',
#   'atom_count': 13,
#   'symbols': ['N', 'N', 'N', 'N', 'C', 'O', 'H', 'C', 'C', 'N', 'H', 'H', 'H'],
#   'coords': array([[-0.72708967,  0.25140722,  0.19294822],
#          [-0.77684276, -0.83609911, -0.58056402],
#          [-0.58214168, -1.96617159,  0.10046872],
#          [-0.34097967, -1.69441092,  1.30874169],
#          [-0.37195743, -0.2848422 ,  1.46677158],
#          [-0.12281148,  0.36005385,  2.4457746 ],
#          [-1.11127727, -0.8388617 , -1.53841606],
#          [ 1.29861674,  1.65822566, -0.63945093],
#          [ 1.43636203,  0.92951136, -1.84648312],
#          [ 1.42532526,  0.25734735, -2.79577458],
#          [ 0.08692107,  1.05155849, -0.15814143],
#          [ 2.03279745,  1.44960466,  0.14638079],
#          [ 0.99137462,  2.70532839, -0.73539004]]),
#   'atom_counter': Counter({'N': 5, 'H': 4, 'C': 3, 'O': 1})},
#  'kfir_rxn_8536': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_8536/calcs/TSs/TS0/conformer4',
#   'atom_count': 14,
#   'symbols': ['O',
#    'N',
#    'C',
#    'C',
#    'N',
#    'C',
#    'N',
#    'O',
#    'C',
#    'N',
#    'N',
#    'C',
#    'H',
#    'H'],
#   'coords': array([[-1.43458409, -1.83809003,  2.20151413],
#          [-0.18359683, -2.28643492,  2.09919458],
#          [ 0.37134873, -1.5942852 ,  1.1356447 ],
#          [-0.61411067, -0.68673843,  0.64394351],
#          [-1.70328058, -0.85401311,  1.30985117],
#          [ 1.72565448, -1.77379363,  0.7178782 ],
#          [ 2.81645751, -1.88550384,  0.35493784],
#          [ 0.33760877,  2.20955781, -0.96055159],
#          [-0.38019464,  1.12125292, -1.25808566],
#          [-0.84751033,  1.09899166, -2.44414215],
#          [-0.41360216,  2.28587333, -3.02395373],
#          [ 0.27153632,  2.89658827, -2.12197876],
#          [-0.5138539 ,  0.20939957, -0.32278009],
#          [ 0.77758654,  3.85625381, -2.18724825]]),
#   'atom_counter': Counter({'N': 5, 'C': 5, 'O': 2, 'H': 2})},
#  'kfir_rxn_11663': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_11663/calcs/TSs/TS0/conformer4',
#   'atom_count': 13,
#   'symbols': ['F', 'C', 'C', 'N', 'N', 'N', 'N', 'O', 'C', 'C', 'O', 'H', 'H'],
#   'coords': array([[ 0.52077466,  3.40203596, -1.62654206],
#          [ 0.37523987,  2.29321213, -0.95967714],
#          [-0.90920129,  1.96770025, -0.43863333],
#          [-0.9603557 ,  0.8279308 ,  0.22796983],
#          [ 0.203184  ,  0.12904434,  0.30023704],
#          [ 1.32663021,  0.43804653, -0.18151414],
#          [ 1.46814802,  1.57500317, -0.83506127],
#          [-0.84440986, -2.88681397, -0.77792366],
#          [-0.8409043 , -3.18525433,  0.37235627],
#          [-0.27370094, -2.20832464,  1.46172984],
#          [-0.18425661, -2.50952862,  2.59923978],
#          [-1.22208683, -4.15154511,  0.78343022],
#          [ 0.06471344, -1.00097597,  0.88987026]]),
#   'atom_counter': Counter({'C': 4, 'N': 4, 'O': 2, 'H': 2, 'F': 1})},
#  'kfir_rxn_8008': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_8008/calcs/TSs/TS0/conformer17',
#   'atom_count': 14,
#   'symbols': ['N',
#    'C',
#    'O',
#    'N',
#    'H',
#    'H',
#    'H',
#    'N',
#    'C',
#    'O',
#    'N',
#    'N',
#    'O',
#    'H'],
#   'coords': array([[-1.10865472, -0.77307775,  1.78481094],
#          [ 0.23187247, -1.12520631,  2.03062091],
#          [ 1.14325339, -0.33799466,  1.92394611],
#          [ 0.39690454, -2.42893156,  2.42164977],
#          [-1.59689428, -1.4836947 ,  1.23208499],
#          [ 1.31095793, -2.66084589,  2.79003538],
#          [-0.38574853, -2.96163948,  2.77696722],
#          [-1.11693378,  1.18954328,  0.34564334],
#          [-0.43304945,  0.85210123, -0.63950629],
#          [-0.08375491,  1.67267517, -1.67321672],
#          [ 0.65483264,  0.93760837, -2.55603735],
#          [ 0.77029466, -0.21644988, -2.15441461],
#          [ 0.11257404, -0.36035064, -0.96178336],
#          [-1.22384997,  0.37162481,  1.20044583]]),
#   'atom_counter': Counter({'N': 5, 'H': 4, 'O': 3, 'C': 2})},
#  'kfir_rxn_11197': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_11197/calcs/TSs/TS0/conformer6',
#   'atom_count': 12,
#   'symbols': ['O', 'C', 'C', 'N', 'H', 'H', 'O', 'C', 'C', 'O', 'H', 'H'],
#   'coords': array([[ 0.32364345,  1.17588433, -1.18092754],
#          [ 0.32720163,  1.99646862, -0.08690455],
#          [-1.01177324,  2.21529605,  0.51138863],
#          [-2.06369932,  2.34643804,  0.97011483],
#          [ 0.75310818,  2.97576154, -0.3787666 ],
#          [ 0.99547178,  1.61184644,  0.71499607],
#          [-0.07072218, -2.62470811, -1.5429128 ],
#          [ 0.32042998, -2.43313413, -0.43412065],
#          [ 0.60503894, -1.00877311,  0.09109974],
#          [ 1.02819482, -0.79309412,  1.1795079 ],
#          [ 0.51670617, -3.23543255,  0.3167011 ],
#          [ 0.37170654, -0.11194609, -0.69220673]]),
#   'atom_counter': Counter({'C': 4, 'H': 4, 'O': 3, 'N': 1})},
#  'kfir_rxn_13897': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_13897/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['N',
#    'C',
#    'N',
#    'N',
#    'C',
#    'H',
#    'H',
#    'N',
#    'C',
#    'O',
#    'N',
#    'N',
#    'O',
#    'H'],
#   'coords': array([[-0.25200028, -1.10880584,  2.62063588],
#          [-0.18780214, -2.47066669,  2.71780146],
#          [ 0.42485391, -2.97288503,  1.68149366],
#          [ 0.78115847, -1.91901632,  0.86745881],
#          [ 0.37994544, -0.84604874,  1.44509806],
#          [-0.64930083, -0.44627044,  3.27320069],
#          [-0.59583795, -3.03897163,  3.55133986],
#          [ 0.61034303,  1.52049411,  0.48164755],
#          [ 0.17748219,  1.44198045, -0.69184829],
#          [ 0.12275674,  2.48685781, -1.5613515 ],
#          [-0.40403416,  2.01753238, -2.73498926],
#          [-0.65822749,  0.82189732, -2.6334104 ],
#          [-0.3244788 ,  0.38028129, -1.37829449],
#          [ 0.57514385,  0.47081482,  0.99204788]]),
#   'atom_counter': Counter({'N': 6, 'C': 3, 'H': 3, 'O': 2})},
#  'kfir_rxn_11797': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_11797/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['F',
#    'C',
#    'C',
#    'N',
#    'N',
#    'N',
#    'N',
#    'O',
#    'C',
#    'C',
#    'Cl',
#    'Cl',
#    'Cl',
#    'H'],
#   'coords': array([[-4.70279000e-05, -3.05007000e+00,  3.10182785e+00],
#          [-1.86564000e-05, -2.86193506e+00,  1.81199638e+00],
#          [-1.22281000e-05, -1.52786022e+00,  1.30757174e+00],
#          [ 2.10655000e-05, -1.56973167e+00,  1.69087919e-02],
#          [ 4.70887000e-05, -2.63080380e+00, -8.06557509e-01],
#          [ 3.50956000e-05, -3.78277082e+00, -2.63092702e-01],
#          [-2.94300000e-07, -3.92571003e+00,  1.06604849e+00],
#          [-9.02206000e-05,  5.51705005e-01, -2.67855660e+00],
#          [-2.42300000e-05,  5.96443525e-01, -1.50477582e+00],
#          [ 9.51070000e-06,  1.88116341e+00, -6.29002969e-01],
#          [-1.46469737e+00,  1.78117716e+00,  3.71337630e-01],
#          [ 1.05229000e-05,  3.34633930e+00, -1.61274195e+00],
#          [ 1.46473884e+00,  1.78115095e+00,  3.71300868e-01],
#          [ 2.41532000e-05, -5.23606003e-01, -6.89468112e-01]]),
#   'atom_counter': Counter({'C': 4, 'N': 4, 'Cl': 3, 'F': 1, 'O': 1, 'H': 1})},
#  'kfir_rxn_2': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_2/calcs/TSs/TS0/conformer6',
#   'atom_count': 10,
#   'symbols': ['N', 'C', 'O', 'N', 'N', 'O', 'N', 'H', 'H', 'H'],
#   'coords': array([[ 0.54365604,  0.24640277, -1.65241468],
#          [ 0.17832258,  0.27376273, -0.46565755],
#          [ 0.33427873,  1.3289258 ,  0.39801285],
#          [-0.19370727,  0.97010031,  1.60143402],
#          [-0.64251117, -0.17207148,  1.54909952],
#          [-0.45376785, -0.68687919,  0.29291087],
#          [-0.10517708, -1.95358592, -2.43286807],
#          [ 0.30918393, -0.81380095, -2.27499445],
#          [ 0.34547968, -2.54528219, -1.72585568],
#          [-1.10092245, -1.95588232, -2.18477899]]),
#   'atom_counter': Counter({'N': 4, 'H': 3, 'O': 2, 'C': 1})},
#  'kfir_rxn_12959': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_12959/calcs/TSs/TS0/conformer6',
#   'atom_count': 13,
#   'symbols': ['C', 'C', 'O', 'H', 'H', 'H', 'O', 'C', 'C', 'N', 'C', 'O', 'H'],
#   'coords': array([[-4.45034011e-01, -2.95494628e+00, -1.13932035e-01],
#          [ 7.12319558e-01, -2.22782838e+00, -7.00193215e-01],
#          [ 1.41533192e+00, -2.40826700e+00, -1.61528380e+00],
#          [-1.32371443e+00, -2.30593548e+00, -2.38581854e-01],
#          [-5.94260766e-01, -3.91504481e+00, -6.27762934e-01],
#          [-2.73268250e-01, -3.10435807e+00,  9.61030593e-01],
#          [-8.32543400e-01,  1.04450649e-01, -9.39923870e-01],
#          [-2.97810735e-01,  6.70238994e-01, -1.30430230e-03],
#          [-5.04904228e-01,  2.09147493e+00,  2.84598521e-01],
#          [-6.91357452e-01,  3.20489190e+00,  5.35278289e-01],
#          [ 7.36253214e-01, -2.57104621e-02,  8.21690905e-01],
#          [ 1.00331610e+00,  6.76308684e-02,  1.98172084e+00],
#          [ 1.09568234e+00, -9.71459595e-01,  1.21047471e-01]]),
#   'atom_counter': Counter({'C': 5, 'H': 4, 'O': 3, 'N': 1})},
#  'kfir_rxn_9679': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_9679/calcs/TSs/TS0/conformer6',
#   'atom_count': 12,
#   'symbols': ['O', 'C', 'C', 'N', 'H', 'H', 'N', 'C', 'O', 'H', 'H', 'H'],
#   'coords': array([[-0.85945362, -1.01566264,  2.7334985 ],
#          [ 0.2166695 , -1.17747905,  1.91955715],
#          [ 0.18144596, -1.3976477 ,  0.60856107],
#          [ 0.15243932, -1.59797967, -0.59525744],
#          [-1.658026  , -0.93458507,  2.20296866],
#          [ 1.17475072, -1.13720414,  2.43984205],
#          [ 0.22388786,  1.41265454, -2.67021715],
#          [ 0.08867638,  0.9775612 , -1.40958983],
#          [-0.06801049,  1.61986566, -0.41129688],
#          [ 0.20640364,  2.40688072, -2.88258979],
#          [ 0.35796811,  0.75536254, -3.42463302],
#          [ 0.14959697, -0.61465053, -1.14046657]]),
#   'atom_counter': Counter({'H': 5, 'C': 3, 'O': 2, 'N': 2})},
#  'kfir_rxn_13108': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_13108/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['O',
#    'C',
#    'C',
#    'C',
#    'C',
#    'O',
#    'H',
#    'C',
#    'C',
#    'N',
#    'O',
#    'N',
#    'H',
#    'H'],
#   'coords': array([[ 2.50878176e-01, -3.30125554e+00, -6.28297028e-02],
#          [ 1.48179158e-01, -2.11955200e+00,  9.16818927e-02],
#          [ 1.04953534e-01, -1.43111405e+00,  1.36722812e+00],
#          [ 4.85737365e-02, -7.83510562e-01,  2.39191870e+00],
#          [ 1.24244392e-02,  8.68638900e-04,  3.62230620e+00],
#          [-9.98761083e-01,  2.30778969e-01,  4.22644107e+00],
#          [ 1.00850369e+00,  3.73601779e-01,  3.95464141e+00],
#          [ 1.24008237e-01,  2.52652937e-01, -1.79388931e+00],
#          [-4.61269132e-02,  7.32914260e-01, -3.12214702e+00],
#          [ 1.38534994e-01,  2.02162365e+00, -3.07439971e+00],
#          [ 4.08362264e-01,  2.32889028e+00, -1.79238302e+00],
#          [ 3.97623886e-01,  1.21968081e+00, -1.00169939e+00],
#          [ 7.70215857e-02, -1.39822800e+00, -7.92250006e-01],
#          [-2.81513193e-01,  2.16708489e-01, -4.04882039e+00]]),
#   'atom_counter': Counter({'C': 6, 'O': 3, 'H': 3, 'N': 2})},
#  'kfir_rxn_9409': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_9409/calcs/TSs/TS0/conformer1',
#   'atom_count': 13,
#   'symbols': ['N', 'N', 'C', 'F', 'N', 'C', 'N', 'C', 'C', 'C', 'O', 'H', 'H'],
#   'coords': array([[-0.22887444,  2.38565656,  2.04775231],
#          [-0.38261403,  2.59323591,  0.73801259],
#          [-0.25892797,  1.56804418, -0.04702335],
#          [-0.40018832,  1.7215509 , -1.33249637],
#          [ 0.00945267,  0.34852246,  0.40407688],
#          [ 0.16559416,  0.11970784,  1.69879748],
#          [ 0.03270202,  1.21470454,  2.52590766],
#          [ 0.27259094, -2.71982399, -3.15101615],
#          [ 0.3327598 , -2.48530368, -1.96318208],
#          [ 0.36511787, -2.02554254, -0.61316086],
#          [ 0.56448415, -2.61526167,  0.40016423],
#          [ 0.22521882, -2.95752963, -4.19924247],
#          [ 0.12834896, -0.62117169, -0.31285503]]),
#   'atom_counter': Counter({'C': 5, 'N': 4, 'H': 2, 'F': 1, 'O': 1})},
#  'kfir_rxn_5989': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_5989/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['O',
#    'C',
#    'C',
#    'N',
#    'C',
#    'N',
#    'H',
#    'O',
#    'C',
#    'C',
#    'N',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-0.02546297,  0.78413247, -0.95509949],
#          [-0.67605081,  1.40614642,  0.08305079],
#          [-2.08422119,  0.97666893,  0.26197095],
#          [-3.18314851,  0.64069242,  0.3637485 ],
#          [ 0.06689112,  1.27105036,  1.36183273],
#          [ 0.70380828,  1.11729889,  2.3120219 ],
#          [-0.69311877,  2.48551662, -0.17045001],
#          [ 0.04887802, -1.38107209, -0.33534232],
#          [ 1.35261108, -1.62590262,  0.05514832],
#          [ 2.3285306 , -1.60111305, -1.04860278],
#          [ 3.08776438, -1.56706938, -1.91755901],
#          [-0.06463785, -0.43828696, -0.90545333],
#          [ 1.6795268 , -0.92718589,  0.84941038],
#          [ 1.35517868, -2.62734043,  0.52122708]]),
#   'atom_counter': Counter({'C': 5, 'H': 4, 'N': 3, 'O': 2})},
#  'kfir_rxn_9885': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/Kfir_HAb_Converged/kfir_rxn_9885/calcs/TSs/TS0/conformer6',
#   'atom_count': 13,
#   'symbols': ['C', 'C', 'O', 'H', 'H', 'H', 'C', 'C', 'O', 'H', 'H', 'H', 'H'],
#   'coords': array([[-0.66961665, -1.38321384,  0.35812662],
#          [ 0.29252872, -1.2767264 ,  1.44566182],
#          [ 0.66802397, -1.64161989,  0.11765025],
#          [-1.39672493, -2.19680724,  0.22368952],
#          [ 0.62758068, -0.28446671,  1.77377467],
#          [ 0.39131814, -2.07511189,  2.19079757],
#          [ 0.12843508,  1.05579804, -1.88509179],
#          [-0.92976079,  1.07425338, -0.81856644],
#          [-1.59159178,  2.00336492, -0.47386545],
#          [ 1.02355933,  0.54930542, -1.49556651],
#          [-0.23906886,  0.44114994, -2.72235726],
#          [ 0.35639766,  2.07057341, -2.23853781],
#          [-1.02731081, -0.06689029, -0.25183153]]),
#   'atom_counter': Counter({'H': 7, 'C': 4, 'O': 2})},
#  'rmg_rxn_15575': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/ZEUS_Converged/rmg_rxn_15575/calcs/TSs/TS0/conf_opt_6',
#   'atom_count': 13,
#   'symbols': ['C', 'H', 'H', 'H', 'C', 'O', 'N', 'C', 'H', 'H', 'H', 'H', 'H'],
#   'coords': array([[ 1.73190581, -0.51685096,  1.99435526],
#          [ 1.6479333 , -0.63656636,  3.0804343 ],
#          [ 2.55326368,  0.13757404,  1.68161972],
#          [ 1.67747187, -1.45824511,  1.43685078],
#          [-0.48812778,  0.73480307,  1.10592014],
#          [-0.38852455,  0.72461108, -0.27772983],
#          [-0.53993239, -0.53828779, -0.77565214],
#          [-0.40995519, -0.57363588, -2.03802528],
#          [ 0.56558149,  0.16215992,  1.60393386],
#          [-1.34992184,  0.16229186,  1.48055719],
#          [-0.48022018,  1.77982848,  1.43718414],
#          [-0.52323034, -1.54729833, -2.51933266],
#          [-0.19648888,  0.32391747, -2.63383315]]),
#   'atom_counter': Counter({'H': 8, 'C': 3, 'O': 1, 'N': 1})},
#  'rmg_rxn_15724': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/ZEUS_Converged/rmg_rxn_15724/calcs/TSs/TS0/conf_opt_6',
#   'atom_count': 29,
#   'symbols': ['C',
#    'O',
#    'N',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'C',
#    'C',
#    'C',
#    'C',
#    'C',
#    'C',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-1.00348848,  2.51453847,  0.7713116 ],
#          [ 0.29927913,  2.61858657,  0.34969207],
#          [ 0.53477237,  1.88359972, -0.78097465],
#          [ 1.76767013,  1.84153766, -1.07672927],
#          [-1.22597252,  3.31840342,  1.4807675 ],
#          [-1.72775249,  2.35837423, -0.03862916],
#          [ 2.03742261,  1.27398161, -1.96990939],
#          [ 2.53712698,  2.33523035, -0.46945256],
#          [ 0.57359665, -1.88424654, -3.68334424],
#          [ 0.39058026, -2.30854907, -2.25771453],
#          [-0.01592383, -1.51023157, -1.26824527],
#          [-0.19854232, -1.93600488,  0.17470562],
#          [-1.6253494 , -1.69967538,  0.60939467],
#          [-1.97688926, -0.76383482,  1.50128226],
#          [-0.99016964,  0.13549874,  2.13806361],
#          [ 0.4171542 , -0.28008029,  1.95886368],
#          [ 0.78225036, -1.21086054,  1.06651274],
#          [ 1.61061162, -2.05048657, -4.01884542],
#          [-0.07347082, -2.46791472, -4.35832357],
#          [ 0.33370005, -0.81937777, -3.82008696],
#          [ 0.61141689, -3.35995581, -2.02916394],
#          [-0.23931603, -0.45467367, -1.46749922],
#          [ 0.01263922, -3.02067258,  0.22517284],
#          [-2.3898358 , -2.32502971,  0.1388146 ],
#          [-3.03195783, -0.63212145,  1.75966856],
#          [-1.08845383,  1.25725943,  1.55187344],
#          [-1.24491818,  0.42162514,  3.16916019],
#          [ 1.17941083,  0.22202765,  2.56179745],
#          [ 1.83856814, -1.46534305,  0.937597  ]]),
#   'atom_counter': Counter({'H': 16, 'C': 11, 'O': 1, 'N': 1})},
#  'rmg_rxn_15670': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/ZEUS_Converged/rmg_rxn_15670/calcs/TSs/TS0/conf_opt_6',
#   'atom_count': 26,
#   'symbols': ['C',
#    'O',
#    'N',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'C',
#    'C',
#    'C',
#    'C',
#    'N',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[ 0.13889558, -1.54841568, -1.35086095],
#          [-1.18123266, -1.15152302, -1.29297908],
#          [-1.72500708, -1.37714375, -0.0549729 ],
#          [-2.88475104, -0.87465175,  0.05312801],
#          [ 0.34643785, -2.44864727, -0.75520851],
#          [ 0.44609921, -1.6079741 , -2.4016607 ],
#          [-3.3976026 , -1.02423351,  1.00529549],
#          [-3.36184604, -0.31117529, -0.75907146],
#          [ 0.2252509 ,  1.92435179, -1.67714657],
#          [ 0.30643726,  1.40682605, -0.26330047],
#          [-0.46188026,  1.91417625,  0.69788826],
#          [-1.16861073,  2.46854012,  1.64829597],
#          [ 1.23686233,  0.39690384, -0.05902139],
#          [ 1.34262076, -0.14466237,  1.28521876],
#          [ 2.46981536, -1.16081821,  1.37466432],
#          [ 1.22747269,  2.21071283, -2.02845067],
#          [-0.1562831 ,  1.1354584 , -2.34451047],
#          [-0.44664379,  2.7888851 , -1.75067296],
#          [-0.77687708,  3.29333386,  2.25639111],
#          [-2.18585875,  2.12662227,  1.87701099],
#          [ 0.9038102 , -0.54058004, -0.78886354],
#          [ 1.54372796,  0.69663694,  1.97037364],
#          [ 0.38677916, -0.59054255,  1.62254054],
#          [ 3.42040435, -0.7118187 ,  1.0518515 ],
#          [ 2.27481293, -2.03375699,  0.73293789],
#          [ 2.5855826 , -1.52426234,  2.40621286]]),
#   'atom_counter': Counter({'H': 15, 'C': 8, 'N': 2, 'O': 1})},
#  'rmg_rxn_15508': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/ZEUS_Converged/rmg_rxn_15508/calcs/TSs/TS0/conf_opt_6',
#   'atom_count': 14,
#   'symbols': ['O',
#    'N',
#    'C',
#    'H',
#    'H',
#    'C',
#    'C',
#    'O',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-2.06074431e+00,  2.40486351e+00, -1.41545290e-01],
#          [-1.00776085e+00,  1.72897224e+00,  4.45374710e-01],
#          [-6.61254586e-01,  6.83203930e-01, -1.49638049e-01],
#          [-2.18544825e+00,  3.16218934e+00,  4.39625402e-01],
#          [-1.08850247e+00,  2.47205092e-01, -1.06513254e+00],
#          [ 1.36812548e+00, -7.19520406e-01,  8.87932162e-01],
#          [ 1.16910847e+00, -2.09129887e+00,  2.93399095e-01],
#          [ 1.04310533e+00, -2.06773659e+00, -1.10639853e+00],
#          [ 3.97039243e-01,  2.10307200e-04,  4.21866341e-01],
#          [ 1.27326770e+00, -6.70431941e-01,  1.98075081e+00],
#          [ 2.27754320e+00, -2.03247733e-01,  5.44361800e-01],
#          [ 2.37928628e-01, -2.53560415e+00,  6.77760739e-01],
#          [ 1.99163654e+00, -2.76466971e+00,  6.15707679e-01],
#          [ 1.83990340e+00, -1.67498753e+00, -1.47483133e+00]]),
#   'atom_counter': Counter({'H': 8, 'C': 3, 'O': 2, 'N': 1})},
#  'rmg_rxn_16548': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/ZEUS_Converged/rmg_rxn_16548/calcs/TSs/TS0/conf_opt_6',
#   'atom_count': 25,
#   'symbols': ['C',
#    'C',
#    'N',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'C',
#    'C',
#    'O',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-0.1493717 ,  2.46626646, -3.75248007],
#          [-0.13829142,  2.35314396, -2.26424294],
#          [-0.11200948,  3.31585239, -1.45884349],
#          [ 0.73535256,  1.96264982, -4.17192584],
#          [-1.03512372,  1.95720781, -4.16247394],
#          [-0.15291989,  3.52129931, -4.06181324],
#          [-0.1560429 ,  1.12889946, -1.84374917],
#          [-0.1062663 ,  3.00708976, -0.48129671],
#          [-0.1735229 , -0.18621188, -1.27861219],
#          [-0.17772216,  0.04320749,  0.20407347],
#          [-0.18202296, -1.18531633,  0.88056039],
#          [-0.1667661 , -1.07266714,  2.27670762],
#          [-0.09916764, -2.46157107,  2.88631681],
#          [ 1.15448891, -3.22924837,  2.48285022],
#          [ 0.73792544, -0.6564436 , -1.66936328],
#          [-1.08944971, -0.63877682, -1.67946151],
#          [-1.06780275,  0.6418828 ,  0.49391691],
#          [ 0.71401824,  0.63680273,  0.50005138],
#          [ 0.70814363, -0.46989268,  2.60376539],
#          [-1.07308165, -0.53975644,  2.63233938],
#          [-0.9980053 , -3.01960666,  2.57670723],
#          [-0.15335073, -2.3597542 ,  3.98271365],
#          [ 2.0639233 , -2.71031041,  2.8259601 ],
#          [ 1.21181371, -3.318496  ,  1.38896423],
#          [ 1.16129735, -4.24138268,  2.91334844]]),
#   'atom_counter': Counter({'H': 16, 'C': 7, 'N': 1, 'O': 1})},
#  'rmg_rxn_16528': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/ZEUS_Converged/rmg_rxn_16528/calcs/TSs/TS0/conf_opt_6',
#   'atom_count': 22,
#   'symbols': ['C',
#    'C',
#    'N',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'C',
#    'C',
#    'O',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[ 0.98650044,  0.19637855, -3.57443751],
#          [ 0.84217074,  0.23314217, -2.07866637],
#          [ 0.10172532,  1.06097194, -1.48209746],
#          [ 2.04249912,  0.32569555, -3.85907863],
#          [ 0.66189911, -0.78244206, -3.96132384],
#          [ 0.38389689,  0.98823448, -4.03805121],
#          [ 1.43372534, -0.52843093, -1.52474911],
#          [ 0.22322455,  0.82347062, -0.2207213 ],
#          [ 0.73731178,  1.74794691,  1.7773691 ],
#          [ 0.46994605,  0.47257832,  1.03101707],
#          [-0.62132003, -0.19121799,  1.53144713],
#          [-0.91640372, -1.41387551,  0.90231   ],
#          [-2.08507243, -2.06392359,  1.60905952],
#          [ 0.98296156,  1.54717545,  2.83318815],
#          [ 1.57734302,  2.28838246,  1.31872893],
#          [-0.15013395,  2.39705334,  1.75132366],
#          [ 1.35609495, -0.18866439,  0.92420013],
#          [-0.02648118, -2.07553324,  0.9303113 ],
#          [-1.15247977, -1.23668722, -0.1638117 ],
#          [-2.96587631, -1.40700376,  1.57592321],
#          [-1.84088922, -2.25873488,  2.66324013],
#          [-2.34247367, -3.01749183,  1.12606237]]),
#   'atom_counter': Counter({'H': 14, 'C': 6, 'N': 1, 'O': 1})},
#  'rmg_rxn_15566': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/ZEUS_Converged/rmg_rxn_15566/calcs/TSs/TS0/conf_opt_6',
#   'atom_count': 13,
#   'symbols': ['N', 'N', 'H', 'H', 'H', 'C', 'O', 'N', 'C', 'H', 'H', 'H', 'H'],
#   'coords': array([[-0.38538321, -1.70761455, -1.57336276],
#          [ 0.92229492, -1.44332335, -1.48689754],
#          [-0.90236727, -0.6787971 , -1.284571  ],
#          [ 1.507958  , -2.27401508, -1.45881206],
#          [ 1.21791308, -0.69092461, -0.85751855],
#          [-1.19708191,  0.66747383, -0.88448793],
#          [-0.88398313,  0.85480513,  0.44976994],
#          [ 0.45829827,  0.74899471,  0.6748248 ],
#          [ 0.76628352,  0.97306554,  1.88582505],
#          [-2.28034334,  0.77130175, -1.00447362],
#          [-0.59096586,  1.2756951 , -1.5725071 ],
#          [ 1.82325884,  0.90246136,  2.14998995],
#          [ 0.01318141,  1.22622377,  2.64289426]]),
#   'atom_counter': Counter({'H': 7, 'N': 3, 'C': 2, 'O': 1})},
#  'rmg_rxn_15545': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/ZEUS_Converged/rmg_rxn_15545/calcs/TSs/TS0/conf_opt_6',
#   'atom_count': 14,
#   'symbols': ['O',
#    'N',
#    'C',
#    'H',
#    'H',
#    'C',
#    'C',
#    'N',
#    'O',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[ 2.12605073,  2.16092126,  1.30111088],
#          [ 1.10027791,  1.31859932,  0.92677876],
#          [ 0.82669652,  0.39709026,  1.72004277],
#          [ 2.18120359,  2.78074725,  0.56573171],
#          [ 1.28517174,  0.14731147,  2.6884504 ],
#          [-1.18177779, -1.00984159,  0.55524018],
#          [-1.2347041 , -0.42268977, -0.7877829 ],
#          [-0.73410524, -1.04925742, -1.7838905 ],
#          [-0.82988347, -0.3295701 , -2.9444546 ],
#          [-0.27301282, -0.4290863 ,  1.17301626],
#          [-2.07095907, -0.81230793,  1.16783506],
#          [-0.89859126, -2.06976324,  0.55320089],
#          [-1.6633648 ,  0.58006745, -0.93192641],
#          [-0.43400804, -0.90940303, -3.60185854]]),
#   'atom_counter': Counter({'H': 7, 'C': 3, 'O': 2, 'N': 2})},
#  'rmg_rxn_15418': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/ZEUS_Converged/rmg_rxn_15418/calcs/TSs/TS0/conf_opt_6',
#   'atom_count': 14,
#   'symbols': ['O',
#    'N',
#    'C',
#    'H',
#    'H',
#    'C',
#    'C',
#    'O',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-2.05636398,  1.60214762, -0.38195414],
#          [-1.19099218,  0.56534607, -0.14297666],
#          [-0.46500521,  0.65775835,  0.86505273],
#          [-2.51152049,  1.33541751, -1.18801006],
#          [-0.41574433,  1.47055695,  1.60554011],
#          [ 1.65576658, -1.362356  , -1.26209325],
#          [ 0.75582709, -1.96363186, -0.19383685],
#          [ 0.91286931, -1.38392237,  1.0613133 ],
#          [ 2.70884329, -1.40364608, -0.9470762 ],
#          [ 1.55350199, -1.90477565, -2.2144974 ],
#          [ 1.38910423, -0.30951094, -1.43978602],
#          [ 0.9819556 , -3.03766194, -0.05304032],
#          [-0.30417131, -1.91793273, -0.51570469],
#          [ 0.34304423, -0.3758233 ,  1.06594557]]),
#   'atom_counter': Counter({'H': 8, 'C': 3, 'O': 2, 'N': 1})},
#  'rmg_rxn_16719': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/ZEUS_Converged/rmg_rxn_16719/calcs/TSs/TS0/conf_opt_6',
#   'atom_count': 12,
#   'symbols': ['C', 'N', 'H', 'H', 'C', 'C', 'N', 'H', 'H', 'H', 'H', 'H'],
#   'coords': array([[-0.13803572,  0.88979057,  2.42541859],
#          [ 0.40418425, -0.1002018 ,  1.87744874],
#          [-0.41952484,  1.80962101,  1.87600997],
#          [-0.35483719,  0.8752769 ,  3.50837048],
#          [-0.09642209, -0.64879651, -2.60526256],
#          [ 0.113127  , -0.56909532, -1.11993669],
#          [ 0.43329654,  0.493148  , -0.52631429],
#          [ 0.60284402, -1.37668823, -3.04479903],
#          [-1.11654005, -1.00150201, -2.82183709],
#          [ 0.05778797,  0.33320935, -3.07060741],
#          [-0.02704469, -1.51230432, -0.55154114],
#          [ 0.54116421,  0.20381674,  0.6826179 ]]),
#   'atom_counter': Counter({'H': 7, 'C': 3, 'N': 2})},
#  'rmg_rxn_16649': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/ZEUS_Converged/rmg_rxn_16649/calcs/TSs/TS0/conf_opt_6',
#   'atom_count': 16,
#   'symbols': ['C',
#    'C',
#    'N',
#    'H',
#    'H',
#    'H',
#    'H',
#    'O',
#    'N',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[ 1.22969970e+00, -2.42575173e+00,  1.85197566e+00],
#          [ 9.26884966e-01, -1.07392316e+00,  1.26846130e+00],
#          [ 1.46461564e+00, -2.88851070e-03,  1.62153808e+00],
#          [ 3.11377370e-01, -2.86378676e+00,  2.27127373e+00],
#          [ 1.99199067e+00, -2.34998184e+00,  2.63742620e+00],
#          [ 1.58408475e+00, -3.10174650e+00,  1.05922134e+00],
#          [ 1.58443121e-01, -1.01639365e+00,  4.51341298e-01],
#          [ 3.94618315e-01,  1.60287470e+00,  1.83390840e-01],
#          [-4.22495602e-01,  7.99318113e-01, -5.14323854e-01],
#          [-6.37042601e-01,  1.14715138e+00, -1.90312475e+00],
#          [-1.71163561e+00,  1.34909283e+00, -8.77201908e-01],
#          [ 1.00681933e+00,  9.27244363e-01,  9.58446435e-01],
#          [-6.92101177e-01,  3.15081509e-01, -2.61089637e+00],
#          [-1.11054442e-01,  2.04048325e+00, -2.25164972e+00],
#          [-1.89533726e+00,  2.37580339e+00, -5.48118781e-01],
#          [-2.56497456e+00,  6.67059084e-01, -8.22860066e-01]]),
#   'atom_counter': Counter({'H': 9, 'C': 4, 'N': 2, 'O': 1})},
#  'rmg_rxn_16506': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/ZEUS_Converged/rmg_rxn_16506/calcs/TSs/TS0/conf_opt_6',
#   'atom_count': 19,
#   'symbols': ['C',
#    'C',
#    'N',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'C',
#    'C',
#    'C',
#    'O',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[ 0.10399373, -0.92515751, -3.10900372],
#          [ 0.37794389, -0.81440387, -1.63734204],
#          [ 1.51426793, -0.49072853, -1.18789976],
#          [-0.24114687, -1.94218675, -3.35265952],
#          [-0.70345901, -0.23245228, -3.39347155],
# ...
#          [-1.51816635,  1.48520843,  0.32781671],
#          [ 0.55303948,  1.13972856, -3.77991145],
#          [-0.32972092, -0.38881372,  0.0277647 ],
#          [-2.06106577, -0.37004985, -0.74243194],
#          [-2.22061669,  2.20506756, -0.12188366],
#          [-1.96082481,  1.1151857 ,  1.26424705],
#          [-0.59011793,  2.02288093,  0.57491365],
#          [ 0.7702987 , -0.97193714,  0.65750234],
#          [ 2.06083138,  0.23796288,  0.70233112],
#          [ 0.44205551, -1.22466998,  1.67288141],
#          [ 0.96819251, -1.85310598,  0.03426043],
#          [ 2.2301993 ,  0.34076715, -0.6330758 ]]),
#   'atom_counter': Counter({'H': 9, 'C': 5, 'S': 1})},
#  'rxn_1632': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/HAb_Converged/rxn_1632/calcs/TSs/TS0/conformer6',
#   'atom_count': 18,
#   'symbols': ['S',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[ 0.21363771, -0.18612908,  2.04832071],
#          [-0.1710789 , -0.75378565,  0.37558016],
#          [ 0.8262853 , -1.6240038 , -0.2730784 ],
#          [ 0.52620929, -2.65567872, -1.07329741],
#          [ 0.1693561 , -1.38987408,  2.65948792],
#          [-1.20478476, -1.11530861,  0.27806074],
#          [ 1.87577603, -1.36316478, -0.09339696],
#          [-0.51105241, -2.94614365, -1.26763498],
#          [ 1.30869103, -3.24504022, -1.55684908],
#          [ 0.21594554,  1.31165612, -2.28919863],
#          [-0.1815265 ,  1.54875591, -1.05206625],
#          [-0.608684  ,  2.75929554, -0.31321233],
#          [ 0.49519762,  0.30264595, -2.6123113 ],
#          [ 0.28196842,  2.11413114, -3.03702367],
#          [-0.18388137,  0.33922292, -0.25823095],
#          [-1.62257608,  2.63404125,  0.09769246],
#          [-0.60598306,  3.64683894, -0.96908684],
#          [ 0.06300477,  2.95535109,  0.53725139]]),
#   'atom_counter': Counter({'H': 11, 'C': 6, 'S': 1})},
#  'rxn_1246': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/HAb_Converged/rxn_1246/calcs/TSs/TS0/conformer6',
#   'atom_count': 14,
#   'symbols': ['C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'S',
#    'C',
#    'C',
#    'S',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-0.08119003, -1.50171449, -2.71134268],
#          [ 0.44709991, -1.76426227, -1.64564292],
#          [ 1.03483665, -1.9550768 , -0.38092935],
#          [-0.5504618 , -1.29271675, -3.65471085],
#          [ 0.91380268, -0.6294315 ,  0.24996178],
#          [ 2.11743745, -2.11927304, -0.34544665],
#          [ 0.45352734, -2.49751538,  0.37361459],
#          [-0.13169411,  0.01118814,  2.39913108],
#          [ 0.69455043,  0.44967736,  0.87785817],
#          [ 0.00743841,  1.23328404, -0.14709044],
#          [-1.6024378 ,  1.42351979, -0.32214262],
#          [-1.37640794,  0.15626654,  1.88291342],
#          [ 1.71956227,  0.79130115,  1.0763866 ],
#          [ 0.6847351 ,  1.6497624 , -0.90800146]]),
#   'atom_counter': Counter({'H': 7, 'C': 5, 'S': 2})},
#  'rxn_1418': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/HAb_Converged/rxn_1418/calcs/TSs/TS0/conformer6',
#   'atom_count': 19,
#   'symbols': ['C',
#    'C',
#    'C',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'C',
#    'C',
#    'C',
#    'S',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-1.0683364 , -0.25103566, -2.33026309],
#          [-1.21375959, -0.09054547, -1.13874682],
#          [-1.29034506,  0.14076167,  0.28365952],
#          [-1.63161044,  1.56773987,  0.70227766],
#          [-1.92435843, -0.90584266,  1.05271239],
#          [-2.4276205 , -1.76649451,  1.74067077],
#          [-0.95878541, -0.39485515, -3.38899498],
#          [-0.03176474,  0.0372403 ,  0.60859559],
#          [-2.66560443,  1.81283086,  0.41619219],
#          [-0.94329812,  2.27128209,  0.21419757],
#          [-1.53266559,  1.67302645,  1.79126681],
#          [-2.88473385, -2.53511663,  2.33561227],
#          [ 1.31393201, -0.18623055,  2.32799158],
#          [ 1.26938224,  0.10540441,  1.0407156 ],
#          [ 2.06213441,  0.50521579, -0.06028262],
#          [ 2.02445025,  2.00921582, -0.73294534],
#          [ 2.24018243, -0.08226148,  2.90333704],
#          [ 0.41908123, -0.52879988,  2.85768903],
#          [ 2.66192994, -0.2907042 , -0.53046212]]),
#   'atom_counter': Counter({'C': 9, 'H': 9, 'S': 1})},
#  'rxn_1401': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/HAb_Converged/rxn_1401/calcs/TSs/TS0/conformer6',
#   'atom_count': 24,
#   'symbols': ['C',
#    'C',
#    'C',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'C',
#    'C',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-1.07133151,  2.22090605, -2.10877305],
#          [-1.11376519,  1.26606577, -1.36400702],
#          [-1.10721928,  0.15925667, -0.43709689],
#          [-1.86376627,  0.38846583,  0.86720968],
#          [-1.26523971, -1.14477124, -1.03717274],
#          [-1.35550468, -2.25972551, -1.50463844],
#          [-1.04756804,  3.06235816, -2.77522503],
#          [ 0.14933716,  0.15254648, -0.01968052],
#          [-2.94508937,  0.4815209 ,  0.68394897],
#          [-1.50768918,  1.31135398,  1.34683583],
#          [-1.69893145, -0.45530165,  1.55188013],
#          [-1.45332182, -3.23986449, -1.9321617 ],
#          [ 1.68729075,  2.39508039,  1.67833728],
#          [ 1.60979182,  1.33172093,  1.09497268],
#          [ 1.45685132,  0.09256394,  0.39577441],
#          [ 1.4625024 , -1.16186677,  1.24644851],
#          [ 2.15854489, -0.01065438, -0.94321117],
#          [ 1.77231311,  3.33320163,  2.19365481],
#          [ 1.0220801 , -2.00141102,  0.68673422],
#          [ 0.89283448, -1.01991126,  2.175463  ],
#          [ 2.49427203, -1.44023731,  1.52172966],
#          [ 3.24600528, -0.13563167, -0.80537417],
#          [ 1.98982897,  0.89078584, -1.54898112],
#          [ 1.78186823, -0.88126137, -1.50189108]]),
#   'atom_counter': Counter({'H': 13, 'C': 11})},
#  'rxn_758': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/HAb_Converged/rxn_758/calcs/TSs/TS0/conformer6',
#   'atom_count': 16,
#   'symbols': ['C',
#    'H',
#    'H',
#    'H',
#    'C',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-0.58813751, -1.38956733,  2.61526202],
#          [-0.04186889, -1.3557015 ,  3.56362139],
#          [-0.32954643, -2.23195033,  1.96521078],
#          [-1.66211078, -1.19328566,  2.70018292],
#          [ 0.07938066, -0.01265169, -2.6268628 ],
#          [ 0.5867075 ,  0.13679072, -1.22641445],
#          [-0.12047233,  0.62132116, -0.19357546],
#          [ 0.36589166,  0.7249282 ,  1.19209461],
#          [ 0.67869291,  0.58376059, -3.33472111],
#          [ 0.14617673, -1.06018741, -2.96470561],
#          [-0.96954259,  0.30705569, -2.71471561],
#          [ 1.62557887, -0.17041869, -1.04736136],
#          [-1.15923878,  0.92742819, -0.37490615],
#          [ 1.4550824 ,  0.62315995,  1.29847104],
#          [-0.00808778,  1.59819587,  1.74377121],
#          [-0.09191055, -0.24504433,  1.85950679]]),
#   'atom_counter': Counter({'H': 11, 'C': 5})},
#  'rxn_1027': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/HAb_Converged/rxn_1027/calcs/TSs/TS0/conformer6',
#   'atom_count': 21,
#   'symbols': ['C',
#    'C',
#    'C',
#    'C',
#    'S',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[ 0.4290056 ,  1.03320015,  1.67301457],
#          [-0.55755333,  0.73036659,  0.57063283],
#          [-1.1823208 , -0.59933432,  0.54221634],
#          [-0.82393176, -1.65393569,  1.29241868],
#          [-1.66494328,  2.09020684,  0.11831561],
#          [-0.06136129,  1.02075838,  2.66142432],
#          [ 1.23780738,  0.28506366,  1.68540095],
#          [ 0.87819304,  2.02515623,  1.52742273],
#          [-1.98561654, -0.72006658, -0.19301564],
#          [-1.32491486, -2.61730485,  1.17401492],
#          [-0.03307022, -1.59537865,  2.0442383 ],
#          [-2.49171097,  1.99992138,  1.18451118],
#          [ 2.40418419, -1.43284173, -0.91890596],
#          [ 2.26979643, -0.09288543, -0.99565531],
#          [ 1.11368675,  0.59376918, -1.54375901],
#          [ 3.2800749 , -1.89116545, -0.45436026],
#          [ 1.6418381 , -2.10389594, -1.32603001],
#          [ 3.05791165,  0.53530366, -0.56369276],
#          [ 0.23880634,  0.71782558, -0.51681194],
#          [ 0.48446081,  0.0150716 , -2.23216256],
#          [ 1.25481466,  1.63556217, -1.85333786]]),
#   'atom_counter': Counter({'H': 13, 'C': 7, 'S': 1})},
#  'rxn_1225': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/HAb_Converged/rxn_1225/calcs/TSs/TS0/conformer6',
#   'atom_count': 15,
#   'symbols': ['C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'C',
#    'C',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-0.68192846, -3.20431725, -0.38306109],
#          [-0.06083534, -2.26502528, -0.84328049],
#          [ 0.65169001, -1.13545517, -1.31211625],
#          [-1.22920401, -4.04028246,  0.01022263],
#          [ 0.62995077, -0.19909348, -0.26854622],
#          [ 0.16358043, -0.53912704, -2.09258652],
#          [ 1.72973861, -1.2674641 , -1.46281978],
#          [-1.67506514,  0.0680775 ,  1.94244394],
#          [-0.647284  ,  0.3872184 ,  1.3870397 ],
#          [ 0.56896653,  0.69868863,  0.68275143],
#          [ 0.64701694,  1.97197712,  0.01024288],
#          [ 0.72702608,  3.01123769, -0.60605477],
#          [-2.58650038, -0.20391559,  2.44063882],
#          [ 1.47537756,  0.45701676,  1.25741405],
#          [ 0.79358127,  3.94321609, -1.13546858]]),
#   'atom_counter': Counter({'C': 8, 'H': 7})},
#  'rxn_901': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/HAb_Converged/rxn_901/calcs/TSs/TS0/conformer6',
#   'atom_count': 18,
#   'symbols': ['C',
#    'C',
#    'C',
#    'C',
#    'S',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[ 0.114402  ,  0.110753  ,  2.14310135],
#          [ 0.01841829,  0.22877379,  0.63170232],
#          [ 1.15060659,  0.84282682, -0.01255406],
#          [ 2.12286308,  1.32690693, -0.55212409],
#          [-1.58658929,  0.81915545,  0.00708681],
#          [ 0.07674907,  1.10324123,  2.62029835],
#          [-0.72153453, -0.48882503,  2.53035217],
#          [ 1.06228404, -0.36981153,  2.42971478],
#          [ 2.97736755,  1.76477067, -1.03279452],
#          [-1.40717207,  2.12495317,  0.3028732 ],
#          [ 0.24618261, -2.08234319, -1.81394378],
#          [-0.0325248 , -2.29029571, -0.353786  ],
#          [-0.51367535, -1.43369924, -2.27591161],
#          [ 1.22923728, -1.61331071, -1.97075295],
#          [ 0.24316407, -3.04064167, -2.3635033 ],
#          [-0.00663622, -0.98187977,  0.19727138],
#          [ 0.75129777, -2.78917964,  0.23075363],
#          [-1.04239545, -2.63052189, -0.08960423]]),
#   'atom_counter': Counter({'H': 11, 'C': 6, 'S': 1})},
#  'rxn_1636': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/HAb_Converged/rxn_1636/calcs/TSs/TS0/conformer6',
#   'atom_count': 16,
#   'symbols': ['S',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[ 0.52396779, -0.29730313,  1.89736529],
#          [-0.24684381, -0.79458807,  0.33453964],
#          [ 0.47019692, -1.74759618, -0.4660047 ],
#          [ 1.07544274, -2.53057671, -1.16682616],
#          [ 0.32453965, -1.45631946,  2.56023533],
#          [-1.31142204, -1.04012772,  0.44930258],
#          [ 1.61244   , -3.2303773 , -1.779192  ],
#          [ 0.40100583,  1.38003822, -2.19595105],
#          [-0.24275444,  1.524596  , -1.0524295 ],
#          [-0.91957342,  2.65146038, -0.36972339],
#          [ 0.83156709,  0.41588379, -2.48723468],
#          [ 0.52895593,  2.22030248, -2.89226006],
#          [-0.27301305,  0.30244232, -0.30982141],
#          [-1.99031439,  2.43846505, -0.22420583],
#          [-0.82987298,  3.58013568, -0.9587508 ],
#          [-0.48339458,  2.82777581,  0.62579737]]),
#   'atom_counter': Counter({'H': 9, 'C': 6, 'S': 1})},
#  'rxn_1040': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/HAb_Converged/rxn_1040/calcs/TSs/TS0/conformer6',
#   'atom_count': 22,
#   'symbols': ['C',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-0.79432434, -1.18563857, -2.28240477],
#          [-1.16795907, -1.17947717, -0.99310529],
#          [-1.22508651, -0.00821922, -0.10352467],
#          [-1.11189418,  1.36850986, -0.719858  ],
#          [-0.53021883, -0.2676386 , -2.81479672],
#          [-0.75313933, -2.11626022, -2.85306989],
#          [-1.42495166, -2.13879892, -0.52725102],
#          [-0.19453713, -0.11376591,  0.67170073],
#          [-2.03924534, -0.08676363,  0.63251023],
#          [-1.91944728,  1.55469059, -1.44793895],
#          [-0.15511143,  1.4928494 , -1.25188044],
#          [-1.16628594,  2.15039827,  0.05128693],
#          [ 1.00843466,  1.13521129,  2.24069776],
#          [ 1.00953425, -0.1281056 ,  1.42178496],
#          [ 2.07990566, -0.27593544,  0.37403571],
#          [ 1.02879478,  2.02878056,  1.59573208],
#          [ 0.11960176,  1.20200837,  2.88637667],
#          [ 1.89677888,  1.19127939,  2.8968698 ],
#          [ 0.84481821, -1.04024273,  2.01477692],
#          [ 3.078173  , -0.41027347,  0.83003776],
#          [ 1.89035296, -1.14476122, -0.27456201],
#          [ 2.13412945,  0.61840407, -0.26792806]]),
#   'atom_counter': Counter({'H': 15, 'C': 7})},
#  'rxn_1371': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/HAb_Converged/rxn_1371/calcs/TSs/TS0/conformer6',
#   'atom_count': 18,
#   'symbols': ['C',
#    'C',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H',
#    'C',
#    'C',
#    'C',
#    'S',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[-0.80393894, -0.64877345, -2.58515458],
#          [-1.02883559, -0.67267599, -1.39417997],
#          [-1.20706884, -0.65045478,  0.02547208],
#          [-2.44548435, -0.18208579,  0.5709151 ],
#          [-3.46107639,  0.25413257,  1.06902871],
#          [-0.62107682, -0.64549885, -3.643709  ],
#          [-0.27313911,  0.29579932,  0.41437612],
#          [-0.76819853, -1.50987293,  0.55251548],
#          [-4.37150571,  0.62705179,  1.50029628],
#          [ 0.62710785,  0.76630599,  2.38385709],
#          [ 0.57145837,  1.16063385,  0.93058482],
#          [ 1.71449577,  0.99163669,  0.05877116],
#          [ 3.00644026,  0.02032472,  0.33832898],
#          [ 1.1448682 , -0.19485531,  2.50905523],
#          [ 1.18455504,  1.51853531,  2.96460027],
#          [-0.38664954,  0.69500653,  2.80465532],
#          [-0.01481155,  2.06645688,  0.71668959],
#          [ 1.6513746 ,  1.532085  , -0.89764949]]),
#   'atom_counter': Counter({'H': 9, 'C': 8, 'S': 1})},
#  'rxn_1818': {'path': '/home/calvin/Dropbox/PersonalFolders/Calvin/HAb_Converged/rxn_1818/calcs/TSs/TS0/conformer6',
#   'atom_count': 19,
#   'symbols': ['C',
#    'C',
#    'C',
#    'C',
#    'S',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'H',
#    'C',
#    'C',
#    'C',
#    'H',
#    'H',
#    'H',
#    'H'],
#   'coords': array([[ 0.5696981 , -0.02406938,  1.98176757],
#          [-0.50009923, -0.1777955 ,  0.92386853],
#          [-0.46273391, -1.37842717,  0.06905218],
#          [ 0.53190694, -2.27641985,  0.02444686],
#          [-2.16989814,  0.3142274 ,  1.43803628],
#          [ 0.4877019 , -0.81442433,  2.74682546],
#          [ 1.57253864, -0.0847841 ,  1.53069627],
#          [ 0.47696806,  0.94876767,  2.48250487],
#          [-1.31751695, -1.49559372, -0.60554266],
#          [ 0.49220283, -3.11861277, -0.66980068],
#          [ 1.40841557, -2.2108119 ,  0.67369257],
#          [-2.45908679, -0.79830821,  2.14883118],
#          [ 0.24287237,  1.74116875, -0.80186127],
#          [ 1.25888616,  1.34328155, -1.46680971],
#          [ 2.30506626,  0.81821226, -2.09468446],
#          [-0.22636671,  0.77520403,  0.08321496],
#          [-0.35589485,  2.64986328, -0.77094346],
#          [ 2.17781253,  0.25564028, -3.02358997],
#          [ 3.31945165,  0.95756854, -1.71082187]]),
#   'atom_counter': Counter({'H': 11, 'C': 7, 'S': 1})},
#  ...}

# %%
import csv
import json

with open("rxn_geometries.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["rxn_id", "path", "atom_count", "symbols", "coords"])

    for rxn_id, info in results.items():
        coords = info["coords"]
        if hasattr(coords, "tolist"):
            coords = coords.tolist()

        writer.writerow([
            rxn_id,
            info["path"],
            info["atom_count"],
            json.dumps(info["symbols"]),
            json.dumps(coords),
        ])

# %%
from rdkit import Chem
from rdkit.Chem import rdmolops

# Load molecules from SDF string or file
suppl = Chem.SDMolSupplier('yourfile.sdf', removeHs=False)
mol_r1h = suppl[0]
mol_r2h = suppl[1]
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 5
#       2 from rdkit.Chem import rdmolops
#       4 # Load molecules from SDF string or file
# ----> 5 suppl = Chem.SDMolSupplier('yourfile.sdf', removeHs=False)
#       6 mol_r1h = suppl[0]
#       7 mol_r2h = suppl[1]
#
# OSError: File error: Bad input file yourfile.sdf

# %%
import json

# Get mol properties
props_r1h = json.loads(mol_r1h.GetProp("mol_properties"))
props_r2h = json.loads(mol_r2h.GetProp("mol_properties"))

d_h_idx = int([k for k, v in props_r1h.items() if v["label"] == "d_hydrogen"][0])
a_h_idx = int([k for k, v in props_r2h.items() if v["label"] == "a_hydrogen"][0])
acceptor_idx = int([k for k, v in props_r2h.items() if v["label"] == "acceptor"][0])

# %%
combined = rdmolops.CombineMols(mol_r1h, mol_r2h_mod)
editable_combined = Chem.EditableMol(combined)

# d_h_idx is from mol_r1h, remains same
# acceptor_idx shifted by number of atoms in mol_r1h
offset = mol_r1h.GetNumAtoms()
acceptor_new_idx = acceptor_idx + offset

# Add bond between donor hydrogen and acceptor
editable_combined.AddBond(d_h_idx, acceptor_new_idx, order=Chem.rdchem.BondType.SINGLE)
mol_final = editable_combined.GetMol()
